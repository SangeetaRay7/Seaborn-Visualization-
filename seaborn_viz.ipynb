# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
wh15=pd.read_csv('World_happiness_2015.csv')
wh16=pd.read_csv('World_happiness_2016.csv')
wh17=pd.read_csv('World_happiness_2017.csv')

# %%
#import pandas_profiling

# %%
#pairplot is matrix plot- all are charts

# %%
import seaborn as sns

# %%
sns.pairplot(wh15) #kind=scatter

# %%
tips_sns=sns.load_dataset('tips')

# %%
sns.pairplot(tips_sns,kind='reg')

# %%
sns.pairplot(tips_sns,kind='kde')

# %%
tips_sns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB

# %%
tips_sns['sex'].unique()
# Out:
# ['Female', 'Male']
# Categories (2, object): ['Female', 'Male']

# %%
sns.pairplot(tips_sns,hue='sex', palette='husl')

# %%
sns.pairplot(tips_sns,hue='day', palette='husl')

# %%
wh15_1=wh15.iloc[:,1:6]

# %%
wh15_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Region                    158 non-null    object
#  1   Happiness Rank            158 non-null    int64
#  2   Happiness Score           158 non-null    float64
#  3   Standard Error            158 non-null    float64
#  4   Economy (GDP per Capita)  158 non-null    float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 6.3+ KB

# %%
sns.pairplot(wh15_1,hue='Region')

# %%
sns.jointplot(wh15['Happiness Score'],wh15['Economy (GDP per Capita)'],hue=wh15['Region'],height=12)
# Out:
# /Users/user/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot(wh15['Happiness Score'],wh15['Economy (GDP per Capita)'],kind='hex',color='blue')
# Out:
# /Users/user/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
